# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
# import datatable as dt
# import evalml
# import seaborn as sns
# from sklearn import preprocessing
# from category_encoders import TargetEncoder
# te = TargetEncoder()

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab data/train_s3TEQDk.csv')
# data=data.drop(data[data['Credit_Product'].isnull()].index)
data['Risk']=data['Vintage']/data['Age']
# data['Poshness']=te.fit_transform(data['Region_Code'],data['Avg_Account_Balance'])
# sns.heatmap(data.corr())
data.corr()
data
# Out:
#               ID  Gender  Age  ... Is_Active Is_Lead      Risk
# 0       NNVBBKZB  Female   73  ...        No       0  0.589041
# 1       IDD62UNG  Female   30  ...        No       0  1.066667
# 2       HD3DSEMC  Female   56  ...       Yes       0  0.464286
# 3       BF3NC7KV    Male   34  ...        No       0  0.558824
# 4       TEASRWXV  Female   30  ...        No       0  1.100000
# ...          ...     ...  ...  ...       ...     ...       ...
# 245720  BPAWWXZN    Male   51  ...        No       0  2.137255
# 245721  HFNB7JY8    Male   27  ...       Yes       0  0.555556
# 245722  GEHAUCWT  Female   26  ...        No       0  0.500000
# 245723  GE7V8SAH  Female   28  ...        No       0  1.107143
# 245724  BOCZSWLJ    Male   29  ...        No       0  0.724138
#
# [245725 rows x 12 columns]

# %%
X=data.drop(['Is_Lead','ID'], axis=1)  
y=data.Is_Lead
X.head()
# Out:
#    Gender  Age Region_Code  ... Avg_Account_Balance Is_Active      Risk
# 0  Female   73       RG268  ...             1045696        No  0.589041
# 1  Female   30       RG277  ...              581988        No  1.066667
# 2  Female   56       RG268  ...             1484315       Yes  0.464286
# 3    Male   34       RG270  ...              470454        No  0.558824
# 4  Female   30       RG282  ...              886787        No  1.100000
#
# [5 rows x 10 columns]

# %%
X_train,X_test,y_train,y_test=evalml.preprocessing.split_data(X,y,problem_type='binary')

# %%
X_train.head()
# Out:
# Data Column           Gender         Age  ...        Risk      Poshness
# Physical Type       category       Int64  ...     float64       float64
# Logical Type     Categorical     Integer  ...      Double        Double
# Semantic Tag(s) ['category'] ['numeric']  ... ['numeric']   ['numeric']
# 818                   Female          81  ...    1.641975  8.653570e+05
# 31657                   Male          29  ...    0.482759  7.328320e+05
# 160309                Female          31  ...    0.806452  8.524428e+05
# 1133                  Female          28  ...    0.750000  8.524428e+05
# 27406                 Female          52  ...    1.750000  1.053188e+06
#
# [5 rows x 11 columns]

# %%
from evalml import AutoMLSearch

# %%
automl=AutoMLSearch(X_train=X_train,y_train=y_train,problem_type='binary',max_batches=1,optimize_thresholds=True)
# Out:
# Generating pipelines to search over...
# 8 pipelines ready for search.

# %%
automl.search()
# Out:
# *****************************
# * Beginning pipeline search *
# *****************************
#
# Optimizing for Log Loss Binary.
# Lower score is better.
#
# Using SequentialEngine to train and score pipelines.
# Searching up to 1 batches for a total of 9 pipelines.
# Allowed model families: extra_trees, random_forest, catboost, decision_tree, linear_model, xgboost, lightgbm
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'name': 'Best Score',
#               'type'…
# Evaluating Baseline Pipeline: Mode Baseline Binary Classification Pipeline
# Mode Baseline Binary Classification Pipeline:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 5.307
#
# *****************************
# * Evaluating Batch Number 1 *
# *****************************
#
# Elastic Net Classifier w/ Imputer + One Hot Encoder + Undersampler + Standard Scaler:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 0.365
# ...

# %%
automl.rankings
# Out:
#    id  ...                                         parameters
# 0   4  ...  {'Imputer': {'categorical_impute_strategy': 'm...
# 1   6  ...  {'Imputer': {'categorical_impute_strategy': 'm...
# 2   3  ...  {'Imputer': {'categorical_impute_strategy': 'm...
# 3   5  ...  {'Imputer': {'categorical_impute_strategy': 'm...
# 4   1  ...  {'Imputer': {'categorical_impute_strategy': 'm...
# 5   7  ...  {'Imputer': {'categorical_impute_strategy': 'm...
# 6   2  ...  {'Imputer': {'categorical_impute_strategy': 'm...
# 7   8  ...  {'Imputer': {'categorical_impute_strategy': 'm...
# 8   0  ...      {'Baseline Classifier': {'strategy': 'mode'}}
#
# [9 rows x 8 columns]

# %%
best_pipeline = automl.best_pipeline

# %%
automl.describe_pipeline(automl.rankings.iloc[7]["id"])
# Out:
# *************************************************
# * CatBoost Classifier w/ Imputer + Undersampler *
# *************************************************
#
# Problem Type: binary
# Model Family: CatBoost
#
# Pipeline Steps
# ...
# 1. Imputer
# 	 * categorical_impute_strategy : most_frequent
# 	 * numeric_impute_strategy : mean
# 	 * categorical_fill_value : None
# 	 * numeric_fill_value : None
# 2. Undersampler
# 	 * sampling_ratio : 0.25
# 	 * min_samples : 100
# 	 * min_percentage : 0.1
# 	 * sampling_ratio_dict : None
# 3. CatBoost Classifier
# 	 * n_estimators : 10
# 	 * eta : 0.03
# 	 * max_depth : 6
# 	 * bootstrap_type : None
# 	 * silent : True
# 	 * allow_writing_files : False
#
# Training
# ...
# Training for binary problems.
# Total training time (including CV): 6.1 seconds
#
# Cross Validation
# ----------------
#             Log Loss Binary MCC Binary   AUC Precision    F1 Balanced Accuracy Binary Accuracy Binary Sensitivity at Low Alert Rates # Training # Validation
# ...

# %%
scores = best_pipeline.score(X_test, y_test,  objectives=evalml.objectives.get_core_objectives('binary'))
print(scores['AUC'])
# Out:
# 0.8047318103772925

# %%
pline=automl.get_pipeline(0)
automl.plot.(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-88cf1b56f669> in <module>()
#       1 pline=automl.get_pipeline(0)
# ----> 2 automl.plot(0)
#
# TypeError: 'PipelineSearchPlots' object is not callable

# %%
pline=automl.get_pipeline(4)
# best_pipeline.feature_importance

# %%
automl_auc = AutoMLSearch(X_train=X_train, y_train=y_train,
                           problem_type='binary',
                           objective='auc',
                           additional_objectives=['precision'],                    
                           optimize_thresholds=True)
automl_auc.search()
# Out:
# Using default limit of max_batches=1.
#
# Generating pipelines to search over...
# 8 pipelines ready for search.
#
# *****************************
# * Beginning pipeline search *
# *****************************
#
# Optimizing for AUC.
# Greater score is better.
#
# Using SequentialEngine to train and score pipelines.
# Searching up to 1 batches for a total of 9 pipelines.
# Allowed model families: extra_trees, random_forest, catboost, decision_tree, linear_model, xgboost, lightgbm
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'name': 'Best Score',
#               'type'…
# Evaluating Baseline Pipeline: Mode Baseline Binary Classification Pipeline
# Mode Baseline Binary Classification Pipeline:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.500
#
# *****************************
# * Evaluating Batch Number 1 *
# *****************************
#
# Elastic Net Classifier w/ Imputer + One Hot Encoder + Standard Scaler:
# ...

# %%
best_pipeline = automl_auc.best_pipeline
best_pipeline.graph()
797702

# %%
best_pipeline.feature_importance
# Out:
#                      feature  importance
# 0        Avg_Account_Balance         617
# 1                        Age         519
# 2                       Risk         482
# 3                    Vintage         436
# 4        Occupation_Salaried         165
# 5              Is_Active_Yes         111
# 6            Channel_Code_X1          78
# 7           Occupation_Other          77
# 8         Credit_Product_Yes          70
# 9              Gender_Female          56
# 10           Channel_Code_X2          53
# 11  Occupation_Self_Employed          44
# 12         Region_Code_RG268          40
# 13         Region_Code_RG254          36
# 14         Region_Code_RG277          35
# 15           Channel_Code_X3          29
# 16         Region_Code_RG283          26
# 17   Occupation_Entrepreneur          21
# 18         Region_Code_RG269          19
# 19         Region_Code_RG284          19
# 20           Channel_Code_X4          19
# 21         Region_Code_RG280          17
# ...

# %%
model_1=automl_auc.best_pipeline
model_1.save('/content/drive/MyDrive/Colab data/LGBM.pkl')
model_1.save('/content/drive/MyDrive/Colab data/LGBM.py')

# %%
import pickle
model1=pickle.load(open('/content/drive/MyDrive/Colab data/LGBM.pkl', 'rb'))
df_test=pd.read_csv('/content/drive/MyDrive/Colab data/test_mSzZ8RL.csv')
df_test['Risk']=df_test['Vintage']/df_test['Age']

# df_test=df_test.drop(df_test[df_test['Credit_Product'].isnull()].index)
# df_test=df_test.drop(df_test[df_test.isnull().index)
# df_test[df_test is None].index
df_test[df_test.isnull()].index
# Out:
# RangeIndex(start=0, stop=105312, step=1)

# %%
redictions=model1.predict(df_test)
predictions.to_series()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-183-917fa6df3faf> in <module>()
# ----> 1 predictions=model1.predict(df_test)
#       2 predictions.to_series()
#
# /usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_meta.py in _check_for_fit(self, X, objective)
#      23                 return method(self, X)
#      24             elif method.__name__ == 'predict':
# ---> 25                 return method(self, X, objective)
#      26             else:
#      27                 return method(self)
#
# /usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py in predict(self, X, objective)
#      81             ww.DataColumn: Estimated labels
#      82         """
# ---> 83         predictions = self._predict(X, objective=objective).to_series()
# ...

# %%
model1
# Out:
# pipeline = BinaryClassificationPipeline(component_graph=[Imputer, OneHotEncoder, LightGBMClassifier], parameters={'Imputer':{'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder':{'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'LightGBM Classifier':{'boosting_type': 'gbdt', 'learning_rate': 0.1, 'n_estimators': 100, 'max_depth': 0, 'num_leaves': 31, 'min_child_samples': 20, 'n_jobs': -1, 'bagging_freq': 0, 'bagging_fraction': 0.9}}, random_seed=0)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-182-d0e90b5e7570> in <module>()
# ----> 1 import model1
#
# ModuleNotFoundError: No module named 'model1'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
